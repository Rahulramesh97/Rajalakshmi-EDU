# %% [markdown]
# # Import libraries

# %%
# Disable warning
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
print(os.listdir("../input"))
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
FAST_RUN=False
batch_size=32
epochs=100
if FAST_RUN:
    epochs=1

# %% [markdown]
# # Import data
# Data input train and test data

# %%
train_data = pd.read_csv("../input/train.csv")
test_data = pd.read_csv("../input/test.csv")

# %% [markdown]
# # Data exploration

# %% [markdown]
# **Columns**

# %%
print(train_data.columns)
# Out:
# Index(['label', 'pixel0', 'pixel1', 'pixel2', 'pixel3', 'pixel4', 'pixel5',
#        'pixel6', 'pixel7', 'pixel8',
#        ...
#        'pixel774', 'pixel775', 'pixel776', 'pixel777', 'pixel778', 'pixel779',
#        'pixel780', 'pixel781', 'pixel782', 'pixel783'],
#       dtype='object', length=785)

# %% [markdown]
# We can see that data have label and other pixels columns. Which label present the digit and pixel present pixel of image

# %% [markdown]
# **Show Image**
# This is how 784 pixels of each row form to be images

# %%
def show_image(train_image, label, index):
    image_shaped = train_image.values.reshape(28,28)
    plt.subplot(3, 6, index+1)
    plt.imshow(image_shaped, cmap=plt.cm.gray)
    plt.title(label)


plt.figure(figsize=(18, 8))
sample_image = train_data.sample(18).reset_index(drop=True)
for index, row in sample_image.iterrows():
    label = row['label']
    image_pixels = row.drop('label')
    show_image(image_pixels, label, index)
plt.tight_layout()

# %% [markdown]
# # Data Preparation
# We split data for test and train

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

x = train_data.drop(columns=['label']).values.reshape(train_data.shape[0],28,28,1)
y = to_categorical(train_data['label'])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=10,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)
train_datagen.fit(x_train)
train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size=batch_size
)

validation_datagen = ImageDataGenerator(rescale=1./255)
train_datagen.fit(x_test)
validation_generator = validation_datagen.flow(
    x_test,
    y_test
    
)

# %% [markdown]
# # Build CNN Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

model = Sequential()
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# # Compile Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Callbacks

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %% [markdown]
# # Fit model

# %%
model.fit_generator(
    train_generator, 
    steps_per_epoch=len(x_train) // batch_size, 
    validation_data=validation_generator,
    validation_steps=len(x_test) // batch_size,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 1181/1181 [==============================] - 16s 14ms/step - loss: 0.3933 - acc: 0.8778 - val_loss: 0.0778 - val_acc: 0.9757
#
# Epoch 00001: val_loss improved from inf to 0.07779, saving model to model.h5
# Epoch 2/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.1711 - acc: 0.9513 - val_loss: 0.0526 - val_acc: 0.9832
#
# Epoch 00002: val_loss improved from 0.07779 to 0.05259, saving model to model.h5
# Epoch 3/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.1350 - acc: 0.9604 - val_loss: 0.0425 - val_acc: 0.9870
#
# Epoch 00003: val_loss improved from 0.05259 to 0.04251, saving model to model.h5
# Epoch 4/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.1156 - acc: 0.9660 - val_loss: 0.0363 - val_acc: 0.9897
#
# Epoch 00004: val_loss improved from 0.04251 to 0.03633, saving model to model.h5
# Epoch 5/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.1073 - acc: 0.9699 - val_loss: 0.0361 - val_acc: 0.9885
#
# Epoch 00005: val_loss improved from 0.03633 to 0.03613, saving model to model.h5
# Epoch 6/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0982 - acc: 0.9714 - val_loss: 0.0329 - val_acc: 0.9897
#
# Epoch 00006: val_loss improved from 0.03613 to 0.03292, saving model to model.h5
# Epoch 7/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0938 - acc: 0.9732 - val_loss: 0.0340 - val_acc: 0.9897
#
# Epoch 00007: val_loss did not improve from 0.03292
# Epoch 8/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0931 - acc: 0.9733 - val_loss: 0.0337 - val_acc: 0.9897
#
# Epoch 00008: val_loss did not improve from 0.03292
# Epoch 9/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0897 - acc: 0.9741 - val_loss: 0.0301 - val_acc: 0.9904
#
# Epoch 00009: val_loss improved from 0.03292 to 0.03012, saving model to model.h5
# Epoch 10/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0865 - acc: 0.9751 - val_loss: 0.0368 - val_acc: 0.9892
#
# Epoch 00010: val_loss did not improve from 0.03012
# Epoch 11/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0835 - acc: 0.9750 - val_loss: 0.0288 - val_acc: 0.9921
#
# Epoch 00011: val_loss improved from 0.03012 to 0.02876, saving model to model.h5
# Epoch 12/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.0859 - acc: 0.9739 - val_loss: 0.0345 - val_acc: 0.9909
#
# Epoch 00012: val_loss did not improve from 0.02876
# Epoch 13/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0826 - acc: 0.9763 - val_loss: 0.0289 - val_acc: 0.9909
#
# Epoch 00013: val_loss did not improve from 0.02876
# Epoch 14/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0884 - acc: 0.9737 - val_loss: 0.0365 - val_acc: 0.9878
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00014: val_loss did not improve from 0.02876
# Epoch 15/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0701 - acc: 0.9792 - val_loss: 0.0300 - val_acc: 0.9914
#
# Epoch 00015: val_loss did not improve from 0.02876
# Epoch 16/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.0651 - acc: 0.9810 - val_loss: 0.0281 - val_acc: 0.9914
#
# Epoch 00016: val_loss improved from 0.02876 to 0.02813, saving model to model.h5
# Epoch 17/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0666 - acc: 0.9809 - val_loss: 0.0309 - val_acc: 0.9916
#
# Epoch 00017: val_loss did not improve from 0.02813
# Epoch 18/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0671 - acc: 0.9803 - val_loss: 0.0232 - val_acc: 0.9926
#
# Epoch 00018: val_loss improved from 0.02813 to 0.02317, saving model to model.h5
# Epoch 19/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0642 - acc: 0.9811 - val_loss: 0.0315 - val_acc: 0.9911
#
# Epoch 00019: val_loss did not improve from 0.02317
# Epoch 20/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0647 - acc: 0.9810 - val_loss: 0.0231 - val_acc: 0.9930
#
# Epoch 00020: val_loss improved from 0.02317 to 0.02311, saving model to model.h5
# Epoch 21/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0650 - acc: 0.9805 - val_loss: 0.0302 - val_acc: 0.9921
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00021: val_loss did not improve from 0.02311
# Epoch 22/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0652 - acc: 0.9808 - val_loss: 0.0265 - val_acc: 0.9926
#
# Epoch 00022: val_loss did not improve from 0.02311
# Epoch 23/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0623 - acc: 0.9813 - val_loss: 0.0246 - val_acc: 0.9933
#
# Epoch 00023: val_loss did not improve from 0.02311
# Epoch 24/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0606 - acc: 0.9817 - val_loss: 0.0274 - val_acc: 0.9904
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00024: val_loss did not improve from 0.02311
# Epoch 25/100
# 1181/1181 [==============================] - 13s 11ms/step - loss: 0.0630 - acc: 0.9818 - val_loss: 0.0259 - val_acc: 0.9926
#
# Epoch 00025: val_loss did not improve from 0.02311
# Epoch 26/100
# 1181/1181 [==============================] - 12s 10ms/step - loss: 0.0643 - acc: 0.9806 - val_loss: 0.0287 - val_acc: 0.9928
#
# Epoch 00026: val_loss did not improve from 0.02311
# Epoch 27/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0624 - acc: 0.9819 - val_loss: 0.0320 - val_acc: 0.9911
#
# Epoch 00027: val_loss did not improve from 0.02311
# Epoch 28/100
# 1181/1181 [==============================] - 11s 10ms/step - loss: 0.0653 - acc: 0.9816 - val_loss: 0.0247 - val_acc: 0.9935
#
# Epoch 00028: val_loss did not improve from 0.02311
# Epoch 29/100
#  720/1181 [=================>............] - ETA: 4s - loss: 0.0691 - acc: 0.9805

# %% [markdown]
# # Evaluate Model

# %%
x_test_recaled = (x_test.astype("float32") / 255)
scores = model.evaluate(x_test_recaled, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print("%s: %.2f%%" % (model.metrics_names[0], scores[0]*100))
# Out:
# acc: 99.24%
# loss: 2.73%

# %% [markdown]
# # Prediction

# %%
test_digit_data = test_data.values.reshape(test_data.shape[0],28,28,1).astype("float32") / 255
predictions = model.predict(test_digit_data)
results = np.argmax(predictions, axis = 1)

# %% [markdown]
# ### Set how is our prediction

# %%
plt.figure(figsize=(18, 8))
sample_test = test_data.head(18)
for index, image_pixels in sample_test.iterrows():
    label = results[index]
    show_image(image_pixels, label, index)
plt.tight_layout()

# %% [markdown]
# ### Create submission file

# %%
submissions = pd.read_csv("../input/sample_submission.csv")
submissions['Label'] = results
submissions.to_csv('submission.csv', index = False)

# %% [markdown]
# Next step check [Dog And Cat Image Classification](https://www.kaggle.com/uysimty/keras-cnn-dog-or-cat-classification)
